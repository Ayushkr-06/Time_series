# %% [markdown]
# # Energy Demand Forecasting with Granite Timeseries (TTM)
#
# TinyTimeMixers (TTMs) are compact pre-trained models for Multivariate Time-Series Forecasting, open-sourced by IBM Research. With less than 1 Million parameters, TTM introduces the notion of the first-ever "tiny" pre-trained models for Time-Series Forecasting. TTM outperforms several popular benchmarks demanding billions of parameters in zero-shot and few-shot forecasting and can easily be fine-tuned for multi-variate forecasts.

# %% [markdown]
# ### Install the TSFM Library
#
# The [granite-tsfm library](https://github.com/ibm-granite/granite-tsfm) provides utilities for working with Time Series Foundation Models (TSFM). Here the pinned version is retrieved and installed.

# %%
import json

# Replace with your actual notebook file name
notebook_path = "your_notebook.ipynb"

# 1. Load the broken notebook
with open(notebook_path, "r", encoding="utf-8") as f:
    nb_data = json.load(f)

# 2. Check for the widgets key and remove it if the state is missing
if "metadata" in nb_data and "widgets" in nb_data["metadata"]:
    if "state" not in nb_data["metadata"]["widgets"]:
        del nb_data["metadata"]["widgets"]
        print("Removed invalid 'widgets' metadata.")

# 3. Save the fixed notebook
with open(notebook_path, "w", encoding="utf-8") as f:
    json.dump(nb_data, f, indent=1)

print("Notebook fixed and saved!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5772/1072741745.py in <cell line: 0>()
#       5
#       6 # 1. Load the broken notebook
# ----> 7 with open(notebook_path, "r", encoding="utf-8") as f:
#       8     nb_data = json.load(f)
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: 'your_notebook.ipynb'

# %%
# !pip install "transformers<4.57.0"
# Out:
# Collecting transformers<4.57.0
#   Downloading transformers-4.56.2-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers<4.57.0) (3.29.0)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers<4.57.0)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.57.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<4.57.0) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.57.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.57.0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers<4.57.0) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<4.57.0) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<4.57.0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers<4.57.0) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<4.57.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<4.57.0) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<4.57.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.57.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.57.0) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.57.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.57.0) (2026.4.22)
# Downloading transformers-4.56.2-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 45.2 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 26.2 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.11.0
#     Uninstalling huggingface_hub-1.11.0:
#       Successfully uninstalled huggingface_hub-1.11.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed huggingface-hub-0.36.2 transformers-4.56.2

# %%
# Install the tsfm library
! pip install "granite-tsfm[notebooks]==0.3.3" "pandas<3"

# %%
# !pip install --upgrade transformers

# %% [markdown]
# ### Import Packages
#
# From `tsfm_public`, we use the TinyTimeMixer model, forecasting pipeline, and plotting function.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import torch

from tsfm_public import (
    TimeSeriesForecastingPipeline,
    TinyTimeMixerForPrediction,
)
from tsfm_public.toolkit.visualization import plot_predictions

# %% [markdown]
# ### Download the data
#
# We'll work with a dataset of hourly electrical demand, generation by type, and weather in Spain. This dataset was originally available from Kaggle. To simplify access to the data, we will make use of the ([energy consumption](https://huggingface.co/datasets/vitaliy-sharandin/energy-consumption-hourly-spain) and [weather](https://huggingface.co/datasets/vitaliy-sharandin/energy-consumption-weather-hourly-spain)) datasets on Hugging Face.

# %%
DATA_FILE_PATH = "hf://datasets/vitaliy-sharandin/energy-consumption-hourly-spain/energy_dataset.csv"

# %% [markdown]
# ### Specify time and output variables
#
# We provide the names of the timestamp column and the target column to be predicted. The context length (in time steps) is set to match the pretrained model.

# %%
timestamp_column = "time"
target_columns = ["total load actual"]
context_length = 512

# %% [markdown]
# ### Read in the data
#
# We parse the csv into a pandas dataframe, filling in any null values, and create a single window containing `context_length` time points. We ensure the timestamp column is a datetime.

# %%
# Read in the data from the downloaded file.
input_df = pd.read_csv(
    DATA_FILE_PATH,
)
input_df[timestamp_column] = pd.to_datetime(input_df[timestamp_column], utc=True)

# Fill NA/NaN values by propagating the last valid value.
input_df = input_df.ffill()

# Only use the last `context_length` rows for prediction.
input_df = input_df.iloc[-context_length:,]

# Show the last few rows of the dataset.
input_df.tail()

# %% [markdown]
# ### Plot the target series
#
# Here we inspect a preview of the target time series column.

# %%
fig, axs = plt.subplots(len(target_columns), 1, figsize=(10, 2 * len(target_columns)), squeeze=False)
for ax, target_column in zip(axs, target_columns):
    ax[0].plot(input_df[timestamp_column], input_df[target_column])

# %% [markdown]
# ### Set up zero shot model
# The TTM model is hosted on [Hugging Face](https://huggingface.co/ibm-granite/granite-timeseries-ttm-v1), and is retrieved by the wrapper, `TinyTimeMixerForPrediction`. We have one input channel in this example.

# %%
# Instantiate the model.
zeroshot_model = TinyTimeMixerForPrediction.from_pretrained(
    "ibm-granite/granite-timeseries-ttm-r2",  # Name of the model on Hugging Face
    num_input_channels=len(target_columns),  # tsp.num_input_channels
)

# %% [markdown]
# ### Create a forecasting pipeline
#
# Set up the forecasting pipeline with the model, setting `frequency` given our knowledge of the sample frequency. In this example we set `explode_forecasts` to `False`, which keeps each sequence of predictions in a list within the dataframe cells. We then make a forecast on the dataset.

# %%
# Create a pipeline.
device = "cuda" if torch.cuda.is_available() else ("mps" if torch.mps.is_available() else "cpu")

pipeline = TimeSeriesForecastingPipeline(
    zeroshot_model,
    timestamp_column=timestamp_column,
    id_columns=[],
    target_columns=target_columns,
    explode_forecasts=False,
    freq="h",
    device=device,  # Specify your local GPU or CPU.
)

# Make a forecast on the target column given the input data.
zeroshot_forecast = pipeline(input_df)
zeroshot_forecast.tail()

# %% [markdown]
# ### Plot predictions along with the historical data.
#
# The predicted series picks up where the historical data ends, and we can see that it predicts a continuation of the cyclical pattern and an upward trend.

# %%
# Plot the historical data and predicted series.
plot_predictions(
    input_df=input_df,
    predictions_df=zeroshot_forecast,
    freq="h",
    timestamp_column=timestamp_column,
    channel=target_column,
    indices=[-1],
    num_plots=1,
)
